# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/master/delaney_solubility_with_descriptors.csv')
df.head()
# Out:
#    MolLogP    MolWt  NumRotatableBonds  AromaticProportion  logS
# 0   2.5954  167.850                0.0                 0.0 -2.18
# 1   2.3765  133.405                0.0                 0.0 -2.00
# 2   2.5938  167.850                1.0                 0.0 -1.74
# 3   2.0289  133.405                1.0                 0.0 -1.48
# 4   2.9189  187.375                1.0                 0.0 -3.04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1144 entries, 0 to 1143
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MolLogP             1144 non-null   float64
#  1   MolWt               1144 non-null   float64
#  2   NumRotatableBonds   1144 non-null   float64
#  3   AromaticProportion  1144 non-null   float64
#  4   logS                1144 non-null   float64
# dtypes: float64(5)
# memory usage: 44.8 KB

# %%
df.columns
# Out:
# Index(['MolLogP', 'MolWt', 'NumRotatableBonds', 'AromaticProportion', 'logS'], dtype='object')

# %%
df.isnull().sum()
# Out:
# MolLogP               0
# MolWt                 0
# NumRotatableBonds     0
# AromaticProportion    0
# logS                  0
# dtype: int64

# %%
X = df.drop(['logS'], axis=1)
y = df['logS']

# %%
X
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %%
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (915, 4)
# (229, 4)
# (915,)
# (229,)

# %% [markdown]
# # Model Build

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
output1 = lr.predict(X_test)
output1
# Out:
# array([-3.05722870e+00, -7.77785827e+00, -2.55016650e+00, -2.01523582e+00,
#        -2.06375990e+00, -9.99672215e-01, -5.94603364e-01, -5.53626003e-01,
#        -5.72200956e+00, -3.94006681e+00, -3.95496755e+00, -2.29737009e+00,
#        -1.48980354e+00, -1.48988982e+00, -4.64510806e+00, -1.90396018e+00,
#        -1.51566313e+00, -3.16424605e+00, -3.70863920e+00, -5.58105660e+00,
#        -3.25038467e+00, -5.04235077e+00, -5.69194881e+00, -2.14339849e+00,
#        -4.35689341e+00, -5.03964756e+00, -3.10383618e+00, -4.40286964e+00,
#        -4.21276272e+00,  5.56508349e-01, -1.45537678e+00, -4.41027396e+00,
#        -2.59668773e+00, -1.53336276e+00, -5.55749874e-01, -1.67111795e+00,
#        -2.78163675e+00, -3.15395565e+00, -5.27083361e+00, -1.75321446e+00,
#        -1.53350725e+00, -2.01255666e+00, -6.57559167e+00, -7.89433046e+00,
#        -5.76437127e+00, -4.16422068e+00, -3.43694663e+00,  1.43834212e+00,
# ...

# %% [markdown]
# ## Performance

# %%
from sklearn.metrics import r2_score, mean_squared_error

print(r2_score(y_test, output1))
print(mean_squared_error(y_test, output1))
# Out:
# 0.7891616188563282
# 1.0206953660861033

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
output2 = rf.predict(X_test)
output2
# Out:
# array([-3.23999333e+00, -8.14085827e+00, -2.27434210e+00, -1.44807940e+00,
#        -5.69121667e-01, -1.93573333e+00, -3.60000000e-03, -1.99988000e+00,
#        -6.27587337e+00, -3.88189000e+00, -4.56279000e+00, -1.86704500e+00,
#        -2.29216333e+00, -1.12459893e+00, -4.12330000e+00, -1.01620714e+00,
#        -7.01160000e-01, -3.87683000e+00, -3.58001000e+00, -4.92832000e+00,
#        -2.50657667e+00, -5.52872734e+00, -6.63883131e+00, -3.50267500e+00,
#        -4.22584000e+00, -4.84398767e+00, -4.65731000e+00, -4.21339667e+00,
#        -4.51917333e+00,  5.51460000e-01, -2.73193000e+00, -4.20550000e+00,
#        -2.61566333e+00, -8.07133333e-01, -7.36665238e-01, -2.49206071e+00,
#        -3.12543000e+00, -2.50773000e+00, -5.19700000e+00, -8.70643333e-01,
#        -5.01010000e-01, -1.73372667e+00, -6.41217286e+00, -6.77308000e+00,
#        -6.35822111e+00, -4.33360333e+00, -3.90378000e+00, -9.26616667e-02,
# ...

# %%
print(r2_score(y_test, output2))
print(mean_squared_error(y_test, output2))
# Out:
# 0.8652217399918412
# 0.6524786649055746

# %%
pd.DataFrame({'Actual':y_test,'Predicted':output1})
# Out:
#       Actual  Predicted
# 822   -3.380  -3.239993
# 118   -8.010  -8.140858
# 347   -2.160  -2.274342
# 1123  -1.170  -1.448079
# 924   -0.730  -0.569122
# ...      ...        ...
# 1114  -4.130  -3.885880
# 427   -9.018  -8.109843
# 711   -0.600  -1.179780
# 4     -3.040  -2.989415
# 948   -2.900  -4.598080
#
# [229 rows x 2 columns]
